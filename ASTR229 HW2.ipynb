# %%
import numpy as np
import matplotlib.pyplot as plt
import astropy

from astropy.io import fits

# %%
my_file = '/Users/wanyan/Desktop/Astro/229/Assignment1/M82-selected/obj0066.fits'
my_image = fits.open(my_file)

# %%
print(my_image[0].header['NAXIS1'], my_image[0].header['NAXIS2'])
# Out:
# 1056 1024

# %%
# medians of all pixel value that are not NaNs
np.nanmedian(my_image[0].data)
# Out:
# np.float64(3759.0)

# %%
z_1 = 3000
z_2 = 8000
plt.imshow(my_image[0].data, origin = 'lower', vmin = z_1, vmax = z_2)
plt.colorbar()

# %%
z_1 = 2500
z_2 = 8000
plt.imshow(my_image[0].data, origin = 'lower', vmin = z_1, vmax = z_2, cmap = 'gray_r')
plt.colorbar()

# %%
z_1 = 2500
z_2 = 8000
plt.imshow(my_image[0].data[250:750, 250:750], origin = 'lower', vmin = z_1, vmax = z_2, cmap = 'gray_r')
plt.colorbar()

# %%
z_1 = 2000
z_2 = 7000
plt.imshow(my_image[0].data, origin = 'lower', vmin = z_1, vmax = z_2, cmap = 'gray_r')
plt.colorbar()

# %%
z_1 = 1500
z_2 = 6000
plt.imshow(my_image[0].data, origin = 'lower', vmin = z_1, vmax = z_2, cmap = 'gray_r')
plt.colorbar()

# %%
z_1 = 2500
z_2 = 8000
plt.imshow(my_image[0].data[49:61, 899:911], origin = 'lower', vmin = z_1, vmax = z_2, cmap = 'gray_r')
plt.colorbar()

# %%
z_1 = 1000
z_2 = 7000
plt.imshow(my_image[0].data[49:61, 899:911], origin = 'lower', vmin = z_1, vmax = z_2, cmap = 'gray_r')
plt.colorbar()

# %%
np.nanmedian(my_image[0].data[49:61, 899:911])
# Out:
# np.float64(3746.0)

# %%
np.nanmean(my_image[0].data[49:61, 899:911])
# Out:
# np.float64(3743.5625)

# %%
z_1 = 1500
z_2 = 6000
plt.imshow(my_image[0].data[0:1024,:], origin = 'lower', vmin = z_1, vmax = z_2, cmap = 'gray_r')
plt.colorbar()

# %%
z_1 = 1500
z_2 = 6000
plt.imshow(my_image[0].data[:,0:1024], origin = 'lower', vmin = z_1, vmax = z_2, cmap = 'gray_r')
plt.colorbar()

# %%
z_1 = 1500
z_2 = 6000
# plt.imshow(my_image[0].data[:,0:1024], origin = 'lower', vmin = z_1, vmax = z_2, cmap = 'gray_r')
plt.imshow(my_image[0].data[:,0:1024], origin = 'lower', cmap = 'gray_r')
plt.colorbar()

# %%
my_image[0].header

#BIASSEC = '[1033:1048,2:1023]'  /  overscan portion of frame                    
#TRIMSEC = '[2:1023,2:1023]   '  /  region to be extracted                       
#DATASEC = '[1:1024,1:1024]   '  /  image portion of frame                       
#CCDSEC  = '[1:1024,1:1024]   '  /  orientation to full frame                    
#ORIGSEC = '[1:1024,1:1024]   '  /  original size full frame      where to trim the image               
#CCDSUM  = '2 2               '  /  on chip summation         why the scale is twice than online.
# Out:
# SIMPLE  =                    T / Fits standard
# BITPIX  =                   16 / Bits per pixel
# NAXIS   =                    2 / Number of axes
# NAXIS1  =                 1056 / Axis length
# NAXIS2  =                 1024 / Axis length
# EXTEND  =                    F / File may contain extensions
# BSCALE  =           1.000000E0 / REAL = TAPE*BSCALE + BZERO
# BZERO   =           3.276800E4 /
# ORIGIN  = 'NOAO-IRAF FITS Image Kernel July 1999' / FITS file originator
# DATE    = '2024-02-15T05:56:09' / Date FITS file was generated
# IRAF-TLM= '2024-02-15T05:55:16' / Time of last modification
# OBJECT  = 'M82     '           / Name of the object observed
# OBSERVAT= 'MCDONALD          '  /  observatory
# OBSERVER= 'mr,ad,cmj         '  /  observers
# EXPTIME =                30.00  /  actual integration time
# DARKTIME=                30.00  /  total elapsed time
# IMAGETYP= 'object            '  /  object, dark, bias, etc.
# ...

# %%
z_1, z_2 = np.percentile(my_image[0].data[1:1024, 1:1024], (1.2, 99))
plt.imshow(my_image[0].data[:,0:1024], origin = 'lower', vmin = z_1, vmax = z_2, cmap = 'gray_r')
plt.colorbar()
plt.title("M82 (Band V, 30 s)", fontsize=14)

plt.savefig("M82_bandV.pdf", format="pdf", bbox_inches="tight")
# i need a title

# %%
z_1, z_2 = np.percentile(my_image[0].data[1:1024, 1:1024], (1.2, 99))
plt.imshow(my_image[0].data[:,0:1024], origin = 'lower', vmin = z_1, vmax = z_2, cmap = 'gray_r')
plt.colorbar()
plt.title("M82 (Band V, 30 s)", fontsize=14)

plt.savefig("M82_bandV.pdf", format="pdf", bbox_inches="tight")
# i need a title
plt.show()
